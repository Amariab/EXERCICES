# %%
import pandas as pd
#pd.options.display.max_rows = 1000
print(pd.__version__)


autos = pd.read_excel("autompg.xlsx",sep = '\t',header = 0)



#print(type(autos)
# Out:
# 0.25.3

# %%
print(autos)
# Out:
#       mpg  cylindres  déplacement  puissance  poids  accélération  \
# 0    18.0          8        307.0      130.0   3504          12.0
# 1    15.0          8        350.0      165.0   3693          11.5
# 2    18.0          8        318.0      150.0   3436          11.0
# 3    16.0          8        304.0      150.0   3433          12.0
# 4    17.0          8        302.0      140.0   3449          10.5
# 5    15.0          8        429.0      198.0   4341          10.0
# 6    14.0          8        454.0      220.0   4354           9.0
# 7    14.0          8        440.0      215.0   4312           8.5
# 8    14.0          8        455.0      225.0   4425          10.0
# 9    15.0          8        390.0      190.0   3850           8.5
# 10   15.0          8        383.0      170.0   3563          10.0
# 11   14.0          8        340.0      160.0   3609           8.0
# 12   15.0          8        400.0      150.0   3761           9.5
# ...

# %%
print(autos.shape)
# Out:
# (398, 9)

# %%
print(autos.head())
# Out:
#     mpg  cylindres  déplacement  puissance  poids  accélération  \
# 0  18.0          8        307.0      130.0   3504          12.0
# 1  15.0          8        350.0      165.0   3693          11.5
# 2  18.0          8        318.0      150.0   3436          11.0
# 3  16.0          8        304.0      150.0   3433          12.0
# 4  17.0          8        302.0      140.0   3449          10.5
#
#    année de modèle  origine          Nom de la voiture
# 0               70        1  chevrolet chevelle malibu
# 1               70        1          buick skylark 320
# 2               70        1         plymouth satellite
# 3               70        1              amc rebel sst
# 4               70        1                ford torino

# %%
print(autos.columns)
# Out:
# Index(['mpg', 'cylindres', 'déplacement', 'puissance', 'poids', 'accélération',
#        'année de modèle', 'origine', 'Nom de la voiture'],
#       dtype='object')

# %%
print(autos.dtypes)
# Out:
# mpg                  float64
# cylindres              int64
# déplacement          float64
# puissance            float64
# poids                  int64
# accélération         float64
# année de modèle        int64
# origine                int64
# Nom de la voiture     object
# dtype: object

# %%
print(autos.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
# mpg                  398 non-null float64
# cylindres            398 non-null int64
# déplacement          398 non-null float64
# puissance            392 non-null float64
# poids                398 non-null int64
# accélération         398 non-null float64
# année de modèle      398 non-null int64
# origine              398 non-null int64
# Nom de la voiture    398 non-null object
# dtypes: float64(4), int64(4), object(1)
# memory usage: 28.1+ KB
# None

# %%
print(autos.describe(include='all'))
# Out:
#                mpg   cylindres  déplacement   puissance        poids  \
# count   398.000000  398.000000   398.000000  392.000000   398.000000
# unique         NaN         NaN          NaN         NaN          NaN
# top            NaN         NaN          NaN         NaN          NaN
# freq           NaN         NaN          NaN         NaN          NaN
# mean     23.514573    5.454774   193.425879  104.469388  2970.424623
# std       7.815984    1.701004   104.269838   38.491160   846.841774
# min       9.000000    3.000000    68.000000   46.000000  1613.000000
# 25%      17.500000    4.000000   104.250000   75.000000  2223.750000
# 50%      23.000000    4.000000   148.500000   93.500000  2803.500000
# 75%      29.000000    8.000000   262.000000  126.000000  3608.000000
# max      46.600000    8.000000   455.000000  230.000000  5140.000000
#
#         accélération  année de modèle     origine Nom de la voiture
# count     398.000000       398.000000  398.000000               398
# ...

# %%
print(autos.mpg)
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
# 5      15.0
# 6      14.0
# 7      14.0
# 8      14.0
# 9      15.0
# 10     15.0
# 11     14.0
# 12     15.0
# 13     14.0
# 14     24.0
# 15     22.0
# 16     18.0
# 17     21.0
# 18     27.0
# 19     26.0
# 20     25.0
# 21     24.0
# 22     25.0
# 23     26.0
# 24     21.0
# 25     10.0
# 26     10.0
# 27     11.0
# 28      9.0
# 29     27.0
# 30     28.0
# 31     25.0
# 32     25.0
# 33     19.0
# 34     16.0
# 35     17.0
# 36     19.0
# 37     18.0
# 38     14.0
# 39     14.0
# 40     14.0
# 41     14.0
# 42     12.0
# 43     13.0
# 44     13.0
# 45     18.0
# 46     22.0
# 47     19.0
# 48     18.0
# 49     23.0
# 50     28.0
# 51     30.0
# 52     30.0
# 53     31.0
# 54     35.0
# 55     27.0
# 56     26.0
# 57     24.0
# 58     25.0
# 59     23.0
# 60     20.0
# 61     21.0
# 62     13.0
# 63     14.0
# 64     15.0
# 65     14.0
# 66     17.0
# 67     11.0
# 68     13.0
# 69     12.0
# 70     13.0
# ...

# %%
print(autos['mpg'])
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
# 5      15.0
# 6      14.0
# 7      14.0
# 8      14.0
# 9      15.0
# 10     15.0
# 11     14.0
# 12     15.0
# 13     14.0
# 14     24.0
# 15     22.0
# 16     18.0
# 17     21.0
# 18     27.0
# 19     26.0
# 20     25.0
# 21     24.0
# 22     25.0
# 23     26.0
# 24     21.0
# 25     10.0
# 26     10.0
# 27     11.0
# 28      9.0
# 29     27.0
# 30     28.0
# 31     25.0
# 32     25.0
# 33     19.0
# 34     16.0
# 35     17.0
# 36     19.0
# 37     18.0
# 38     14.0
# 39     14.0
# 40     14.0
# 41     14.0
# 42     12.0
# 43     13.0
# 44     13.0
# 45     18.0
# 46     22.0
# 47     19.0
# 48     18.0
# 49     23.0
# 50     28.0
# 51     30.0
# 52     30.0
# 53     31.0
# 54     35.0
# 55     27.0
# 56     26.0
# 57     24.0
# 58     25.0
# 59     23.0
# 60     20.0
# 61     21.0
# 62     13.0
# 63     14.0
# 64     15.0
# 65     14.0
# 66     17.0
# 67     11.0
# 68     13.0
# 69     12.0
# 70     13.0
# ...

# %%
print(autos[['mpg','cylindres']])
# Out:
#       mpg  cylindres
# 0    18.0          8
# 1    15.0          8
# 2    18.0          8
# 3    16.0          8
# 4    17.0          8
# 5    15.0          8
# 6    14.0          8
# 7    14.0          8
# 8    14.0          8
# 9    15.0          8
# 10   15.0          8
# 11   14.0          8
# 12   15.0          8
# 13   14.0          8
# 14   24.0          4
# 15   22.0          6
# 16   18.0          6
# 17   21.0          6
# 18   27.0          4
# 19   26.0          4
# 20   25.0          4
# 21   24.0          4
# 22   25.0          4
# 23   26.0          4
# 24   21.0          6
# 25   10.0          8
# 26   10.0          8
# 27   11.0          8
# 28    9.0          8
# 29   27.0          4
# 30   28.0          4
# 31   25.0          4
# 32   25.0          4
# 33   19.0          6
# 34   16.0          6
# 35   17.0          6
# 36   19.0          6
# 37   18.0          6
# 38   14.0          8
# 39   14.0          8
# 40   14.0          8
# 41   14.0          8
# ...

# %%
print(autos['mpg'].head())
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# 3    16.0
# 4    17.0
# Name: mpg, dtype: float64

# %%
print(autos['mpg'].tail())
# Out:
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, dtype: float64

# %%
print(autos['mpg'].describe())
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
print(autos['mpg'].mean())
# Out:
# 23.514572864321615

# %%
print(autos['cylindres'].value_counts())
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylindres, dtype: int64

# %%
print(autos['mpg'][0])
# Out:
# 18.0

# %%
print(autos['mpg'][0:3])
# Out:
# 0    18.0
# 1    15.0
# 2    18.0
# Name: mpg, dtype: float64

# %%
print(autos['mpg'].sort_values())
# Out:
# 28      9.0
# 25     10.0
# 26     10.0
# 103    11.0
# 124    11.0
# 27     11.0
# 67     11.0
# 95     12.0
# 104    12.0
# 90     12.0
# 106    12.0
# 42     12.0
# 69     12.0
# 213    13.0
# 85     13.0
# 44     13.0
# 43     13.0
# 215    13.0
# 87     13.0
# 214    13.0
# 62     13.0
# 92     13.0
# 73     13.0
# 94     13.0
# 96     13.0
# 208    13.0
# 137    13.0
# 70     13.0
# 68     13.0
# 105    13.0
# 166    13.0
# 91     13.0
# 74     13.0
# 38     14.0
# 65     14.0
# 41     14.0
# 40     14.0
# 39     14.0
# 159    14.0
# 138    14.0
# 8      14.0
# 11     14.0
# 13     14.0
# 75     14.0
# 93     14.0
# 7      14.0
# 6      14.0
# 86     14.0
# 63     14.0
# 139    14.0
# 140    14.0
# 88     14.0
# 190    14.5
# 64     15.0
# 121    15.0
# 128    15.0
# 157    15.0
# 154    15.0
# 155    15.0
# 89     15.0
# 72     15.0
# 115    15.0
# 162    15.0
# 1      15.0
# 5      15.0
# 9      15.0
# 10     15.0
# 12     15.0
# 224    15.0
# 290    15.5
# 230    15.5
# ...

# %%
print(autos['mpg'].argsort())
# Out:
# 0       28
# 1       25
# 2       26
# 3      103
# 4      124
# 5       27
# 6       67
# 7       95
# 8      104
# 9       90
# 10     106
# 11      42
# 12      69
# 13     213
# 14      85
# 15      44
# 16      43
# 17     215
# 18      87
# 19     214
# 20      62
# 21      92
# 22      73
# 23      94
# 24      96
# 25     208
# 26     137
# 27      70
# 28      68
# 29     105
# 30     166
# 31      91
# 32      74
# 33      38
# 34      65
# 35      41
# 36      40
# 37      39
# 38     159
# 39     138
# 40       8
# 41      11
# 42      13
# 43      75
# 44      93
# 45       7
# 46       6
# 47      86
# 48      63
# 49     139
# 50     140
# 51      88
# 52     190
# 53      64
# 54     121
# 55     128
# 56     157
# 57     154
# 58     155
# 59      89
# 60      72
# 61     115
# 62     162
# 63       1
# 64       5
# 65       9
# 66      10
# 67      12
# 68     224
# 69     290
# 70     230
# 71     223
# 72     231
# 73     189
# 74     188
# 75       3
# ...

# %%
print(autos.sort_values(by='mpg').head())
# Out:
#       mpg  cylindres  déplacement  puissance  poids  accélération  \
# 28    9.0          8        304.0      193.0   4732          18.5
# 25   10.0          8        360.0      215.0   4615          14.0
# 26   10.0          8        307.0      200.0   4376          15.0
# 103  11.0          8        400.0      150.0   4997          14.0
# 124  11.0          8        350.0      180.0   3664          11.0
#
#      année de modèle  origine Nom de la voiture
# 28                70        1          hi 1200d
# 25                70        1         ford f250
# 26                70        1         chevy c20
# 103               73        1  chevrolet impala
# 124               73        1  oldsmobile omega

# %%
for col in autos.columns: print(autos[col].dtype)
# Out:
# float64
# int64
# float64
# float64
# int64
# float64
# int64
# int64
# object

# %%
import numpy
#fonction call back
def operation(x):
    return(x.mean())

# %%
resultat = autos.select_dtypes(exclude=['object']).apply(operation,axis=0) print(resultat)
# Out:
#   File "<ipython-input-42-9b1f8ee03432>", line 1
#     resultat = autos.select_dtypes(exclude=['object']).apply(operation,axis=0) print(resultat)
#                                                                                    ^
# SyntaxError: invalid syntax

# %%
matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
autos.hist(column='mpg')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd4527ad450>]],
#       dtype=object)

# %%
#density plot
autos['mpg'].plot.kde()

# %%
#histogrammes de l'âge selon le sexe
autos.hist(column='mpg',by='origine')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fd440b3f110>,
# ...
#       dtype=object)

# %%
#scatterplot : age vs. tauxmax
autos.plot.scatter(x='mpg',y='origine')
